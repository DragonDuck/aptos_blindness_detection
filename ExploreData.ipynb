# %% [markdown]
# This notebook explores the data and its attributes

# %%
import os
from PIL import Image
import numpy as np
import pandas as pd

# %%
img_dir = "train_images/"

# %%
file_list = [img_dir + f for f in os.listdir(img_dir)]
print("There are {} images.".format(len(file_list)))
# Out:
# There are 3662 images.

# %%
img_sizes = []
for file in file_list:
    img = Image.open(file)
    img_sizes.append((img.width, img.height))
print("Unique image dimensions:")
for entry in set(img_sizes):
    print(" - " + str(entry))
# Out:
# Unique image dimensions:
#  - (1476, 1117)
#  - (2048, 1536)
#  - (4288, 2848)
#  - (1504, 1000)
#  - (819, 614)
#  - (1050, 1050)
#  - (640, 480)
#  - (2896, 1944)
#  - (2416, 1736)
#  - (3388, 2588)
#  - (1844, 1226)
#  - (2144, 1424)
#  - (2146, 1764)
#  - (3216, 2136)
#  - (2588, 1958)
#  - (1467, 1110)
#  - (474, 358)

# %%
labels = pd.read_csv("test.csv")

# %%
labels
# Out:
#            id_code
# 0     0005cfc8afb6
# 1     003f0afdcd15
# 2     006efc72b638
# 3     00836aaacf06
# 4     009245722fa4
# 5     009c019a7309
# 6     010d915e229a
# 7     0111b949947e
# 8     01499815e469
# 9     0167076e7089
# 10    01c31b10ab99
# 11    01c5ba195207
# 12    01e4d86b3a30
# 13    020921b796d5
# 14    020f6983114d
# 15    021c207614d6
# 16    0229c0a80d42
# 17    024d0a225db1
# 18    0268f4382c67
# 19    0299d97f31f7
# 20    03042a663e54
# 21    030e06ddbb04
# 22    033cdbbbdfaa
# 23    03be80919be4
# 24    03eaa4eef484
# 25    0434995d0654
# 26    04a0773c71fb
# 27    04e1b77ef107
# 28    051d9d12a6ee
# 29    052e00f47cfa
# ...            ...
# 1898  fc66648f758e
# 1899  fc67df1e574e
# 1900  fc6c9d0efe53
# 1901  fc79feb5deed
# 1902  fcbc1f4b5342
# 1903  fcd166e6e4b5
# 1904  fcea00df9f33
# 1905  fd2978398705
# 1906  fd2d58c6cd45
# 1907  fd4d81b43e84
# 1908  fd7cc592106e
# 1909  fd8e6b0b2e45
# 1910  fda8612fcc8c
# 1911  fdde61dd1bde
# 1912  fde8778182af
# ...
